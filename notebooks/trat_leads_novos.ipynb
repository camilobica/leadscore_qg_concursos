# %% [markdown]
# # Tratamento de Dados - Leads Novos

# %%
import gspread
import numpy as np
import os
import pandas as pd
import pytz
import re
import requests
import unicodedata

from datetime import datetime
from dotenv import load_dotenv
from google.oauth2 import service_account
from gspread_dataframe import set_with_dataframe
from oauth2client.service_account import ServiceAccountCredentials
from pathlib import Path

# === Carregar variáveis de ambiente ===
load_dotenv(Path.cwd().parent / "secrets" / ".env", override=True)

# === Definir escopos de acesso ===
scopes = [
    "https://www.googleapis.com/auth/spreadsheets.readonly",
    "https://www.googleapis.com/auth/drive.readonly"
]

# === Caminho seguro para o arquivo JSON (lido do .env) ===
cred_path = Path.cwd().parent / os.getenv("GOOGLE_CREDENTIALS_PATH")

# === Carregar credenciais de forma moderna ===
creds = service_account.Credentials.from_service_account_file(
    str(cred_path),
    scopes=scopes
)

# === Autorizar o cliente gspread ===
client = gspread.authorize(creds)

# === Função para carregar aba da planilha ===
def carregar_aba(sheet_id, aba_nome):
    planilha = client.open_by_key(sheet_id)
    aba = planilha.worksheet(aba_nome)
    dados = aba.get_all_records()
    return pd.DataFrame(dados)

# === IDs das planilhas (fixar no .env depois se quiser) ===
id_leads_l34 = "155-8YH18_ExLOLq0kWQTz1rolB4903hV6_MfD1FubkQ"
id_invest_trafego_l34 = "1A7W3qqCjDDP8oDpjLt6hZHLs68a1wmD1kWn47StFOTE"

# === Carregar DataFrames ===
df_leads_l34_forms = carregar_aba(id_leads_l34, "Respostas ao formulário 1")
df_dados_invest_face = carregar_aba(id_invest_trafego_l34, "Dados Investimento")
df_dados_invest_google = carregar_aba(id_invest_trafego_l34, "Dados Investimento Google")

# Corrige coluna 'spend' para float, tratando formatos BR se necessário
df_dados_invest_face["spend"] = (
    df_dados_invest_face["spend"]
    .astype(str)
    .str.replace(".", "", regex=False)
    .str.replace(",", ".", regex=False)
    .str.strip()
    .replace("", np.nan)
    .astype(float)
) / 100 


df_dados_invest_google["spend"] = (
    df_dados_invest_google["spend"]
    .astype(str)                       # garante string
    .str.replace(".", "", regex=False)  # remove milhar (se houver)
    .str.replace(",", ".", regex=False)  # troca decimal
    .str.strip()
    .replace("", np.nan)               # trata strings vazias
    .astype(float)                     # converte de vez
) / 1000

# %% [markdown]
# # Pesquisa Leads Forms

# %%
df_leads_l34_forms.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2473 entries, 0 to 2472
# Data columns (total 14 columns):
#  #   Column                                                                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                                                                    --------------  -----
#  0   Carimbo de data/hora                                                                                                                      2473 non-null   object
#  1   Nome completo                                                                                                                             2473 non-null   object
#  2   Seu melhor e-mail                                                                                                                         2473 non-null   object
#  3   Número de WhatsApp                                                                                                                        2473 non-null   object
#  4   Qual estado você reside?                                                                                                                  2473 non-null   object
#  5   Qual sua faixa de idade?                                                                                                                  2473 non-null   object
#  6   Qual seu nível de escolaridade?                                                                                                           2473 non-null   object
#  7   Qual sua faixa salarial atualmente?                                                                                                       2473 non-null   object
#  8   Qual seu estado civil?                                                                                                                    2473 non-null   object
#  9   Você tem filhos?                                                                                                                          2473 non-null   object
#  10  Por que você escolheu/escolheria a profissão de Policial Civil?                                                                           2473 non-null   object
#  11  O que está IMPEDINDO você de conquistar o seu DISTINTIVO e ser o próximo POLICIAL CIVIL? Qual sua maior dificuldade?                      2473 non-null   object
#  12  O que você espera aprender/ver no evento Operação Policial Civil - 2025?                                                                  2473 non-null   object
#  13  Imagine que você está em uma mentoria individual com o Prof. Luis Costa, quais seriam as 3 principais perguntas que você faria para ele?  2473 non-null   object
# dtypes: object(14)
# memory usage: 270.6+ KB

# %%
df_leads_l34_forms.drop(columns=[
    "O que você espera aprender/ver no evento Operação Policial Civil - 2025? ",
    "Imagine que você está em uma mentoria individual com o Prof. Luis Costa, quais seriam as 3 principais perguntas que você faria para ele?"
], inplace=True)

# %%
# Renomear colunas do df_leads_google
colunas_renomeadas = {
    'Carimbo de data/hora': 'data',
    'Seu melhor e-mail': 'email',
    'Nome completo': 'nome',
    'Número de WhatsApp': 'whatsapp',
    'Qual estado você reside?': 'estado',
    'Qual sua faixa de idade?': 'idade',
    'Qual seu nível de escolaridade?': 'escolaridade',
    'Qual sua faixa salarial atualmente?': 'renda',
    'Qual seu estado civil?': 'estado_civil',
    'Você tem filhos?': 'filhos',
    'Por que você escolheu/escolheria a profissão de Policial Civil?': 'escolheu_profissao',
    'O que está IMPEDINDO você de conquistar o seu DISTINTIVO e ser o próximo POLICIAL CIVIL? Qual sua maior dificuldade?': 'dificuldade'
}

df_leads_l34_forms.rename(columns=colunas_renomeadas, inplace=True)

# Normalizar e deduplicar e-mails
if 'email' in df_leads_l34_forms.columns:
    df_leads_l34_forms['email'] = df_leads_l34_forms['email'].astype(str).str.lower().str.strip()

# Exibir resumo
df_leads_l34_forms.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2473 entries, 0 to 2472
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   data                2473 non-null   object
#  1   nome                2473 non-null   object
#  2   email               2473 non-null   object
#  3   whatsapp            2473 non-null   object
#  4   estado              2473 non-null   object
#  5   idade               2473 non-null   object
#  6   escolaridade        2473 non-null   object
#  7   renda               2473 non-null   object
#  8   estado_civil        2473 non-null   object
#  9   filhos              2473 non-null   object
#  10  escolheu_profissao  2473 non-null   object
#  11  dificuldade         2473 non-null   object
# dtypes: object(12)
# memory usage: 232.0+ KB

# %%
df_leads_l34_forms["renda"] = (
    df_leads_l34_forms["renda"]
    .replace({
        "De R$ 1.000,00 a R$ 3.000,00": "De 1.000 a 3.000",
        "De R$ 3.000,00 a R$ 5.000,00": "De 3.000 a 5.000",
        "Até R$ 1.000,00": "Até 1.000",
        "Não estou trabalhando no momento": "Desempregado",
        "Acima de R$ 5.000,00": "Acima de 5.000"
    })
)

# %%
# Normalize o dicionário para garantir que as chaves estejam em minúsculo
estado_siglas = {
    k.lower(): v for k, v in {
        'são paulo': 'SP',
        'sp': 'SP',
        'rio de janeiro': 'RJ',
        'rj': 'RJ',
        'minas gerais': 'MG',
        'mg': 'MG',
        'bahia': 'BA',
        'ba': 'BA',
        'goiás': 'GO',
        'goias': 'GO',
        'go': 'GO',
        'paraná': 'PR',
        'pr': 'PR',
        'espírito santo': 'ES',
        'es': 'ES',
        'rio grande do sul': 'RS',
        'rs': 'RS',
        'santa catarina': 'SC',
        'sc': 'SC',
        'alagoas': 'AL',
        'al': 'AL',
        'paraíba': 'PB',
        'paraiba': 'PB',
        'pb': 'PB',
        'pará': 'PA',
        'pa': 'PA',
        'maranhão': 'MA',
        'ma': 'MA',
        'pernambuco': 'PE',
        'pe': 'PE',
        'amazonas': 'AM',
        'am': 'AM',
        'rio grande do norte': 'RN',
        'rn': 'RN',
        'distrito federal': 'DF',
        'df': 'DF',
        'boa vista': 'RR',
        'rr': 'RR',
        'ceará': 'CE',
        'brasília': 'DF',
        'brasilia': 'DF',
        'florianopolis': 'SC',
        'guarulhos': 'SP',
        'guarujá': 'SP',
        'Rio das ostras': 'RJ',
        'Granja': 'RJ',
        'Ceara': 'CE',
        'Tocantins': 'TO',
        'Belém': 'PA',
        'Acre': 'AC',
        'Rondônia': 'RO',
        'Itanhaém': 'SP',
        'Rio de janriro': 'RJ',
        'Volta redonda': 'RJ',
        'Botucatu': 'SP',
        'Mogi mirim': 'SP',
        'Feira de Santana': 'BA',
        'Recife': 'PE',
        'Joinville': 'SC',
        'São Bento do Sul': 'SC',
        'Juazeiro do norte': 'CE'
    }.items()
}

# Função de normalização
def normalizar_estado(valor):
    if pd.isna(valor):
        return None
    texto = str(valor).lower().strip()
    for nome, sigla in estado_siglas.items():
        if nome in texto:
            return sigla
    return valor

# Aplicar a função
df_leads_l34_forms['estado'] = df_leads_l34_forms['estado'].apply(normalizar_estado)

# Verificar resultado final
print(df_leads_l34_forms['estado'].value_counts(dropna=False))
# Out:
# estado
# SP                    1610
# MG                     185
# BA                     100
# PR                      92
# RS                      78
# SC                      76
# RJ                      70
# PE                      69
# GO                      36
# MA                      35
# CE                      33
# AL                      28
# DF                      21
# PA                       6
# ES                       6
# RN                       5
# Florianópolis            2
# AM                       2
# AC                       1
# Piaui                    1
# Conde                    1
# Ipu-ce                   1
# Vila Rica MT             1
# Avaré                    1
# Río grande do sul        1
# Piauí                    1
# Piauí                    1
# Concórdia                1
# PB                       1
# Gandu                    1
# CE                       1
# Góiase                   1
# Ce                       1
# MT                       1
# Jaraguá do sul           1
# TO                       1
# Ipiau BH                 1
# Name: count, dtype: int64

# %%
# Categorias permitidas
CATEGORIAS_PERMITIDAS = {
    'médio completo',
    'superior completo',
    'fundamental completo',
    'superior incompleto',
    'técnico',
    'médio incompleto',
    'fundamental incompleto'
}

# 1. Pré-processamento
def limpar_texto(texto):
    texto = str(texto).lower().strip()
    return unicodedata.normalize('NFKD', texto).encode('ASCII', 'ignore').decode('utf-8')

# 2. Substituições comuns
SUBSTITUICOES = {
    'imcompleto': 'incompleto',
    'inclopeto': 'incompleto',
    'incompleta': 'incompleto',
    'enfetmagem': 'enfermagem',
    'encino': 'ensino',
    'esino': 'ensino',
    'ensaio': 'ensino',
    'ensino superior incomoda': 'superior incompleto',
    'sup incompleto mais cursando': 'superior incompleto',
    'superior curso': 'superior incompleto',
    'superior engenharia mecanica incompleto': 'superior incompleto',
    'comecei direito, mas nao finalizei': 'superior incompleto',
    'faco radiologia': 'superior incompleto',
}

def aplicar_substituicoes(val):
    for k, v in SUBSTITUICOES.items():
        val = val.replace(k, v)
    return val

# 3. Mapeamento explícito
MAPEAMENTO_EXPLICITO = {
    'incompleto': 'superior incompleto',
    'none': None,
    'cursando': 'superior incompleto',
    'setimo ano': 'fundamental incompleto',
    'comecando a faculdade': 'superior incompleto',
    'cursando terceiro ano medio': 'médio incompleto',
    'bombeira civil': 'técnico',
    'sim': None,
    'auxiliar de enfermagem': 'técnico',
    'enfermagem': 'superior incompleto',
    '5 seria': 'fundamental incompleto',
    '8 seria': 'fundamental incompleto',
    'estudante': 'médio incompleto',
    'pos graduado': 'superior completo',
    'estou no 2°ano ensino medio': 'médio incompleto',
    'e completo': 'médio completo',
    'cursando pedagogia': 'superior incompleto',
    'cursando gestao em rh': 'superior incompleto',
    "2'ano": 'fundamental incompleto',
    'tec enfermagem': 'técnico',
    'ciencias contabeis': 'superior incompleto',
    'ensino medio completando': 'médio incompleto',
    '2': 'fundamental incompleto',
    'cursando o supervisor': 'superior incompleto',
    'estudar ainda': 'médio incompleto',
    'cursando gestao agronegocio': 'superior incompleto',
    'terapeuta ocupacional ( cursando)': 'superior incompleto',
    'engenharia nao concluida': 'superior incompleto',
    'preciso terminar o ensino fundamental': 'fundamental incompleto',
    'alguns certificados na area da seguranca': 'técnico',
}

def aplicar_mapeamento_explicito(val):
    return MAPEAMENTO_EXPLICITO.get(val)

# 4. Categorização padrão
def categorizar_padrao(val):
    if any(p in val for p in ['fundamental incompleto', 'parei no', 'nao terminei fundamental', 'nono ano', 'quint', 'sere', 'serie']) \
       or re.search(r'\b[1-9]{1,2}[ºo]?\s*(ano|serie)', val) and 'medio' not in val:
        return 'fundamental incompleto'
    
    if 'fundamental completo' in val or 'primeiro grau completo' in val:
        return 'fundamental completo'

    if any(p in val for p in ['ensino medio incompleto', 'medio incompleto', '2º colegial incompleto', 'eja', 'ensino medio nao']):
        return 'médio incompleto'

    if any(p in val for p in ['ensino medio completo', 'medio completo', 'magisterio']):
        return 'médio completo'

    if any(p in val for p in ['superior completo', 'graduacao completa', 'nivel superior completo', 'pos-graduacao', 'pos graduacao']) \
       or ('graduacao' in val and 'cursando' not in val and 'incompleto' not in val):
        return 'superior completo'

    if any(p in val for p in ['tecnico', 'tecnologo', 'tecnologia', 'curso tec']):
        return 'técnico'

    if any(v in val for v in ['cursando', 'concluindo', 'fazendo', 'em andamento', 'graduando', 'estudando', 'terminando']):
        if any(n in val for n in ['superior', 'faculdade', 'universidade', 'direito', 'biomedicina', 'administracao']):
            return 'superior incompleto'
        elif 'ensino medio' in val or 'medio' in val or 'colegial' in val:
            return 'médio incompleto'
        elif 'fundamental' in val or 'serie' in val:
            return 'fundamental incompleto'

    if re.search(r'[0-9]{1,2}.*semestre', val) or 'periodo' in val:
        return 'superior incompleto'

    return val

# 5. Ajustes finais
AJUSTES_FINAIS = {
    'pos graduado': 'superior completo',
    'pos graduada': 'superior completo',
    'pos-graduacao': 'superior completo',
    'pos-graduada': 'superior completo',
    'pos graduado em gestao de projetos': 'superior completo',
    'mestrado': 'superior completo',
    'mba': 'superior completo',
    'cursando graduacao': 'superior incompleto',
    'cursando graduacao em radiologia': 'superior incompleto',
    'cursando graduacao em enfermagem': 'superior incompleto',
    'cursanso ensino superior': 'superior incompleto',
    'cursanso faculdade': 'superior incompleto',
    'superior incompleto ☹️': 'superior incompleto',
    'estou, termiando o ensino medio!': 'médio incompleto',
    '8 incompleto': 'fundamental incompleto',
}

def aplicar_ajustes_finais(val):
    return AJUSTES_FINAIS.get(val, val)

# --------------------------
# Função principal
# --------------------------
def normalizar_escolaridade(valor):
    if pd.isna(valor):
        return None

    val = limpar_texto(valor)
    val = aplicar_substituicoes(val)

    mapeado = aplicar_mapeamento_explicito(val)
    if mapeado:
        val = mapeado
    else:
        val = categorizar_padrao(val)

    val = aplicar_ajustes_finais(val)

    if val not in CATEGORIAS_PERMITIDAS:
        return None

    return val

# %%
df_leads_l34_forms['escolaridade_original'] = df_leads_l34_forms['escolaridade']
df_leads_l34_forms['escolaridade'] = df_leads_l34_forms['escolaridade_original'].apply(normalizar_escolaridade)

df_leads_l34_forms['escolaridade'].value_counts()
# Out:
# escolaridade
# médio completo            1661
# superior completo          335
# fundamental completo       284
# superior incompleto         78
# técnico                     27
# médio incompleto            25
# fundamental incompleto      20
# Name: count, dtype: int64

# %%
# Função de limpeza de texto
def limpar_texto(texto):
    texto = str(texto).strip().lower()
    texto = unicodedata.normalize('NFKD', texto).encode('ASCII', 'ignore').decode('utf-8')
    texto = re.sub(r'[^\w\s]', '', texto)  # remove pontuação
    return texto

# Mapeamento por categoria
def normalizar_estado_civil(valor):
    if pd.isna(valor):
        return None

    val = limpar_texto(valor)

    if val in {'solteiroa', 'solteiro', 'viuvo solteiro'}:
        return 'solteiro(a)'

    if val in {'casadoa', 'tenho esposa e filhos mais nao casado formalmente'}:
        return 'casado(a)'

    if val in {
        'divorciadoa ou separadora', 'divorciadoa', 'separado', 'separada', 'em processo de separacao',
        'divorciando', 'divorciado uniao estavel'
    }:
        return 'divorciado(a)'

    if val in {
        'uniao estavel', 'moro junto', 'mora junto', 'moramos juntos', 'morando junto',
        'morando com alguem', 'convivente', 'amigado', 'amigada', 'amaziado',
        'moro com um pessoal', 'tenho companheira e filhos', 'moro a 20 anos',
        'moro a mais de 5 anos com minha conjuge', 'ajuntado sem uniao estavel', 'namorando'
    } or 'moro junto' in val or 'com meu parceiro' in val:
        return 'união estável'

    if val in {'viuva', 'viuvo', 'viuva de companheiro'}:
        return 'viúvo(a)'

    return valor  # mantém valor original se não reconhecido

# Ajustes finais de exceções residuais
AJUSTES_FINAIS_ESTADO_CIVIL = {
    'vendendor autonomo e sou vigilante': None,
    'estou terminado o ensino medio': None,
    '5serie': None,
    'enrolada': 'união estável',
    'leandro alves': None
}

def aplicar_ajustes_finais_estado_civil(valor):
    if valor in CATEGORIAS_VALIDAS_ESTADO_CIVIL:
        return valor  # já está padronizado

    val_limpo = limpar_texto(valor)
    return AJUSTES_FINAIS_ESTADO_CIVIL.get(val_limpo, None)  # se não reconhecido, descarta

# Categorias válidas
CATEGORIAS_VALIDAS_ESTADO_CIVIL = {
    'solteiro(a)',
    'casado(a)',
    'divorciado(a)',
    'união estável',
    'viúvo(a)'
}

# %%
df_leads_l34_forms['estado_civil_original'] = df_leads_l34_forms['estado_civil']
df_leads_l34_forms['estado_civil'] = df_leads_l34_forms['estado_civil_original'].apply(normalizar_estado_civil)

df_leads_l34_forms['estado_civil'].value_counts()
# Out:
# estado_civil
# solteiro(a)                                             927
# casado(a)                                               908
# união estável                                           317
# Divorciado(a) ou Separado(a)                            298
# viúvo(a)                                                 11
# Amasiado                                                  2
# Tenho esposa mas não nO papel                             1
# X                                                         1
# Convivência                                               1
# Morando junto com minha esposa a quase 11 anos            1
# Morando junto mais nao no papel                           1
# Divorciado porém atualmente moro com um cônjuge           1
# Se conhecendo                                             1
# Amaciado                                                  1
# Divorciado oficialmente,  porem convvo a 18 juntos.i      1
# divorciado(a)                                             1
# Name: count, dtype: int64

# %%
# Categorias válidas para dificuldade
DIFICULDADES_VALIDAS = {
    'financeiro / dinheiro',
    'falta de tempo',
    'falta de base escolar',
    'falta de oportunidade',
    'idade'
}

# Função de limpeza e normalização
def limpar_dificuldade_simples(valor):
    if pd.isna(valor):
        return None

    val = str(valor).strip().lower().strip("., ")

    if val in DIFICULDADES_VALIDAS:
        return val
    return None

# %%
df_leads_l34_forms['dificuldade_original'] = df_leads_l34_forms['dificuldade']
df_leads_l34_forms['dificuldade'] = df_leads_l34_forms['dificuldade_original'].apply(limpar_dificuldade_simples)

df_leads_l34_forms['dificuldade'].value_counts()
# Out:
# dificuldade
# financeiro / dinheiro    1194
# falta de tempo            512
# falta de base escolar     375
# idade                     223
# falta de oportunidade      21
# Name: count, dtype: int64

# %%
# Excluir colunas que terminam com "_original"
df_leads_l34_forms.drop(
    columns=[col for col in df_leads_l34_forms.columns if col.endswith('_original')],
    inplace=True
)

# %%
df_leads_l34_forms.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2473 entries, 0 to 2472
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   data                2473 non-null   object
#  1   nome                2473 non-null   object
#  2   email               2473 non-null   object
#  3   whatsapp            2473 non-null   object
#  4   estado              2473 non-null   object
#  5   idade               2473 non-null   object
#  6   escolaridade        2430 non-null   object
#  7   renda               2473 non-null   object
#  8   estado_civil        2473 non-null   object
#  9   filhos              2473 non-null   object
#  10  escolheu_profissao  2473 non-null   object
#  11  dificuldade         2325 non-null   object
# dtypes: object(12)
# memory usage: 232.0+ KB

# %%
df_leads_l34_forms = df_leads_l34_forms.drop(columns=['nome'])

# %%
features = ["renda", "escolaridade", "idade", "estado_civil", "filhos", 'escolaridade', 'escolheu_profissao', 'dificuldade']

for col in features:
    if col in df_leads_l34_forms.columns:
        df_leads_l34_forms[col] = df_leads_l34_forms[col].astype(str).str.strip().str.lower()

# %%
colunas_excluir = ["data", "email", "whatsapp", "nome"]

for coluna in df_leads_l34_forms.columns:
    if coluna not in colunas_excluir:
        print(f"\nColuna: {coluna}")
        print(df_leads_l34_forms[coluna].value_counts(dropna=False))
# Out:
# Coluna: estado
# estado
# SP                    1610
# MG                     185
# BA                     100
# PR                      92
# RS                      78
# SC                      76
# RJ                      70
# PE                      69
# GO                      36
# MA                      35
# CE                      33
# AL                      28
# DF                      21
# PA                       6
# ES                       6
# RN                       5
# Florianópolis            2
# AM                       2
# AC                       1
# Piaui                    1
# Conde                    1
# Ipu-ce                   1
# Vila Rica MT             1
# Avaré                    1
# Río grande do sul        1
# Piauí                    1
# Piauí                    1
# Concórdia                1
# PB                       1
# Gandu                    1
# CE                       1
# Góiase                   1
# Ce                       1
# MT                       1
# Jaraguá do sul           1
# TO                       1
# Ipiau BH                 1
# Name: count, dtype: int64
#
# Coluna: idade
# idade
# 36 - 45 anos        1001
# 26 - 35 anos         675
# 46 - 55 anos         613
# até 25 anos          160
# acima de 56 anos      24
# Name: count, dtype: int64
#
# Coluna: escolaridade
# escolaridade
# médio completo            1661
# superior completo          335
# fundamental completo       284
# superior incompleto         78
# none                        43
# técnico                     27
# médio incompleto            25
# fundamental incompleto      20
# Name: count, dtype: int64
#
# Coluna: renda
# renda
# de 1.000 a 3.000    1286
# de 3.000 a 5.000     526
# até 1.000            291
# desempregado         264
# acima de 5.000       106
# Name: count, dtype: int64
#
# Coluna: estado_civil
# estado_civil
# solteiro(a)                                             927
# casado(a)                                               908
# união estável                                           317
# divorciado(a) ou separado(a)                            298
# viúvo(a)                                                 11
# amasiado                                                  2
# tenho esposa mas não no papel                             1
# x                                                         1
# convivência                                               1
# morando junto com minha esposa a quase 11 anos            1
# morando junto mais nao no papel                           1
# divorciado porém atualmente moro com um cônjuge           1
# se conhecendo                                             1
# amaciado                                                  1
# divorciado oficialmente,  porem convvo a 18 juntos.i      1
# divorciado(a)                                             1
# Name: count, dtype: int64
#
# Coluna: filhos
# filhos
# sim    1904
# não     569
# Name: count, dtype: int64
#
# Coluna: escolheu_profissao
# escolheu_profissao
# sonho de criança                                                                                                                                                                                                                                                                                    902
# gosta da profissão                                                                                                                                                                                                                                                                                  814
# estabilidade de emprego                                                                                                                                                                                                                                                                             412
# prestígio da carreira                                                                                                                                                                                                                                                                               207
# segurança                                                                                                                                                                                                                                                                                            98
# nasci para ser policial                                                                                                                                                                                                                                                                               1
# sempre gostei da profissão,e pela também pela estabilidade de emprego                                                                                                                                                                                                                                 1
# meu pai era pm militar. aí depois que ele faliceu. eu mim teresei pela carreira militar.                                                                                                                                                                                                              1
# complexo                                                                                                                                                                                                                                                                                              1
# trocar de instituição                                                                                                                                                                                                                                                                                 1
# satisfação profissional                                                                                                                                                                                                                                                                               1
# meu pai era pm militar aí depôs. que ele faliceu eu mim apaixonei pela carreira militar. como era o meu pai tbm só tem eu dos filhos dele que tem vontade de seguir a mesma carreira que o meu pai era policial. eu sou vigilânte mais eu quero mais eu quero. ser policial igual a meu pai era.      1
# estabilidade e amor a profissão                                                                                                                                                                                                                                                                       1
# todos os ponto acima.                                                                                                                                                                                                                                                                                 1
# todas as opções anteriores                                                                                                                                                                                                                                                                            1
# quando novo perdi a minha única oportunidade de servir o batalhão caveira no exército brasileiro de itu,por conta de uma paixão de adolescente, me arrependo até os dias de hj minha farda jogada aos porcos.                                                                                         1
# já trabalhei no estado como agente socioeducativo na fundação casa                                                                                                                                                                                                                                    1
# sempre gostei                                                                                                                                                                                                                                                                                         1
# todas as alternativas                                                                                                                                                                                                                                                                                 1
# inspiração meu pai                                                                                                                                                                                                                                                                                    1
# trabalho                                                                                                                                                                                                                                                                                              1
# já trabalhei como escrivão ad hoc                                                                                                                                                                                                                                                                     1
# sonho de criança e estabilidade de emprego                                                                                                                                                                                                                                                            1
# reformado na pmmg                                                                                                                                                                                                                                                                                     1
# gosto da profissão policial, e também pelo prestigio da carreira, realização de um sonho                                                                                                                                                                                                              1
# detetive                                                                                                                                                                                                                                                                                              1
# todo mundo que me conhece fala que eu tenho cara de polícia, e como eu já gosto da profissão resolvi arriscar.                                                                                                                                                                                        1
# uma junção de sonho com prestígio e estabilidade.                                                                                                                                                                                                                                                     1
# estudo investigação e perícia criminal                                                                                                                                                                                                                                                                1
# gosto de investigação e ajudar o próximo.                                                                                                                                                                                                                                                             1
# x                                                                                                                                                                                                                                                                                                     1
# sempre quis ser investigador                                                                                                                                                                                                                                                                          1
# ganhar um bom dinheiro                                                                                                                                                                                                                                                                                1
# paixão pela profissão                                                                                                                                                                                                                                                                                 1
# tentar ajudar nossa sociedade                                                                                                                                                                                                                                                                         1
# já trabalho na área algum tempo e já passei em alguns concursos. meu sonho passar na polícia civil sp                                                                                                                                                                                                 1
# vocação                                                                                                                                                                                                                                                                                               1
# a lei foi instruída pelo profeta moisés pelo criador jeová                                                                                                                                                                                                                                            1
# poder                                                                                                                                                                                                                                                                                                 1
# quero novo conhecimento                                                                                                                                                                                                                                                                               1
# vontade de ser um pc                                                                                                                                                                                                                                                                                  1
# trabalho na delegacia                                                                                                                                                                                                                                                                                 1
# estabilidade de emprego e prestigio da carreira                                                                                                                                                                                                                                                       1
# pra mim é uma honra ter esse mérito! e amo fazer o trabalho do bem!                                                                                                                                                                                                                                   1
# me identifico com a carreira                                                                                                                                                                                                                                                                          1
# Name: count, dtype: int64
#
# Coluna: dificuldade
# dificuldade
# financeiro / dinheiro    1194
# falta de tempo            512
# falta de base escolar     375
# idade                     223
# none                      148
# falta de oportunidade      21
# Name: count, dtype: int64

# %% [markdown]
# # Leads Novos

# %%
parquet_leads_antigos = Path.cwd().parent / "dados" / "leads_antigos.parquet"
parquet_alunos_antigos = Path.cwd().parent / "dados" / "alunos_antigos.parquet"
parquet_leads_l34 = Path.cwd().parent / "dados" / "leads_l34.parquet"

df_leads = pd.read_parquet(parquet_leads_antigos)
df_alunos = pd.read_parquet(parquet_alunos_antigos)
df_leads_l34 = pd.read_parquet(parquet_leads_l34)

# %%
df_leads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10863 entries, 0 to 10862
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   data                10863 non-null  datetime64[ns]
#  1   lancamentos         10863 non-null  object
#  2   email               10863 non-null  object
#  3   whatsapp            10863 non-null  object
#  4   estado              10863 non-null  object
#  5   idade               10863 non-null  object
#  6   escolaridade        10863 non-null  object
#  7   renda               10863 non-null  object
#  8   estado_civil        10863 non-null  object
#  9   filhos              10863 non-null  object
#  10  escolheu_profissao  10863 non-null  object
#  11  dificuldade         10863 non-null  object
#  12  comprou             10863 non-null  int32
#  13  utm_source          10817 non-null  object
#  14  utm_medium          10690 non-null  object
#  15  utm_campaign        10840 non-null  object
#  16  utm_content         10092 non-null  object
#  17  utm_term            6529 non-null   object
# dtypes: datetime64[ns](1), int32(1), object(16)
# memory usage: 1.5+ MB

# %%
df_alunos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   data                260 non-null    datetime64[ns]
#  1   lancamentos         260 non-null    object
#  2   email               260 non-null    object
#  3   whatsapp            260 non-null    object
#  4   estado              260 non-null    object
#  5   idade               260 non-null    object
#  6   escolaridade        260 non-null    object
#  7   renda               260 non-null    object
#  8   estado_civil        260 non-null    object
#  9   filhos              260 non-null    object
#  10  escolheu_profissao  260 non-null    object
#  11  dificuldade         260 non-null    object
#  12  comprou             260 non-null    int32
#  13  utm_source          259 non-null    object
#  14  utm_medium          243 non-null    object
#  15  utm_campaign        258 non-null    object
#  16  utm_content         196 non-null    object
#  17  utm_term            82 non-null     object
# dtypes: datetime64[ns](1), int32(1), object(16)
# memory usage: 35.7+ KB

# %%
df_leads_l34.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22488 entries, 0 to 22487
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         22488 non-null  object
#  1   nome                       22488 non-null  object
#  2   email                      22488 non-null  object
#  3   telefone                   22488 non-null  object
#  4   data inscrição lançamento  22488 non-null  object
#  5   estado                     18284 non-null  object
#  6   idade                      17979 non-null  object
#  7   escolaridade               17991 non-null  object
#  8   renda                      18117 non-null  object
#  9   estado civil               18056 non-null  object
#  10  filhos                     18153 non-null  object
#  11  escolheu profissão         18207 non-null  object
#  12  dificuldade                17061 non-null  object
#  13  email captação             18284 non-null  object
#  14  telefone captação          18282 non-null  object
#  15  utm_source                 22456 non-null  object
#  16  utm_campaign               21972 non-null  object
#  17  utm_medium                 21458 non-null  object
#  18  utm_content                21028 non-null  object
#  19  utm_term                   19242 non-null  object
# dtypes: object(20)
# memory usage: 3.4+ MB

# %%
taxa_resposta_por_canal = (
    df_leads_l34
    .groupby('utm_source')['email captação']
    .apply(lambda x: x.notna().mean())
    .to_dict()
)

# %%
display(taxa_resposta_por_canal)
# Out:
# {'EMAILMKT': 0.8181818181818182,
#  'Facebook-Ads': 0.8105085784313726,
#  'INSTAGRAM': 0.9151785714285714,
#  'TIKTOK': 0.8571428571428571,
#  'WHATSAPP': 0.8947368421052632,
#  'YOUTUBE': 0.7916666666666666,
#  'fb': 0.7777777777777778,
#  'google': 0.8571428571428571,
#  'google-ads': 0.8219584569732937,
#  'search': 1.0,
#  'teste': 0.0}

# %%
df_leads_l34 = df_leads_l34[df_leads_l34['email captação'].notna()].reset_index(drop=True)

# %%
df_leads_l34.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18284 entries, 0 to 18283
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         18284 non-null  object
#  1   nome                       18284 non-null  object
#  2   email                      18284 non-null  object
#  3   telefone                   18284 non-null  object
#  4   data inscrição lançamento  18284 non-null  object
#  5   estado                     18284 non-null  object
#  6   idade                      17979 non-null  object
#  7   escolaridade               17991 non-null  object
#  8   renda                      18117 non-null  object
#  9   estado civil               18056 non-null  object
#  10  filhos                     18153 non-null  object
#  11  escolheu profissão         18207 non-null  object
#  12  dificuldade                17061 non-null  object
#  13  email captação             18284 non-null  object
#  14  telefone captação          18282 non-null  object
#  15  utm_source                 18259 non-null  object
#  16  utm_campaign               17854 non-null  object
#  17  utm_medium                 17454 non-null  object
#  18  utm_content                17074 non-null  object
#  19  utm_term                   15598 non-null  object
# dtypes: object(20)
# memory usage: 2.8+ MB

# %%
df_leads_l34.isnull().sum()
# Out:
# id                              0
# nome                            0
# email                           0
# telefone                        0
# data inscrição lançamento       0
# estado                          0
# idade                         305
# escolaridade                  293
# renda                         167
# estado civil                  228
# filhos                        131
# escolheu profissão             77
# dificuldade                  1223
# email captação                  0
# telefone captação               2
# utm_source                     25
# utm_campaign                  430
# utm_medium                    830
# utm_content                  1210
# utm_term                     2686
# dtype: int64

# %%
df_leads_l34 = df_leads_l34.drop(columns=['id', 'email', 'telefone', 'nome'])

colunas_renomeadas = {
    'data inscrição lançamento': 'data',
    'email captação': 'email',
    'telefone captação': 'whatsapp',
    'Qual estado você reside?': 'estado',
    'Qual sua faixa de idade?': 'idade',
    'Qual seu nível de escolaridade?': 'escolaridade',
    'Qual sua faixa salarial atualmente?': 'renda',
    'estado civil': 'estado_civil',
    'Você tem filhos?': 'filhos',
    'escolheu profissão': 'escolheu_profissao'
}

df_leads_l34.rename(columns=colunas_renomeadas, inplace=True)

df_leads_l34.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18284 entries, 0 to 18283
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   data                18284 non-null  object
#  1   estado              18284 non-null  object
#  2   idade               17979 non-null  object
#  3   escolaridade        17991 non-null  object
#  4   renda               18117 non-null  object
#  5   estado_civil        18056 non-null  object
#  6   filhos              18153 non-null  object
#  7   escolheu_profissao  18207 non-null  object
#  8   dificuldade         17061 non-null  object
#  9   email               18284 non-null  object
#  10  whatsapp            18282 non-null  object
#  11  utm_source          18259 non-null  object
#  12  utm_campaign        17854 non-null  object
#  13  utm_medium          17454 non-null  object
#  14  utm_content         17074 non-null  object
#  15  utm_term            15598 non-null  object
# dtypes: object(16)
# memory usage: 2.2+ MB

# %%
df_leads_l34["renda"] = (
    df_leads_l34["renda"]
    .replace({
        "De R$ 1.000,00 a R$ 3.000,00": "De 1.000 a 3.000",
        "De R$ 3.000,00 a R$ 5.000,00": "De 3.000 a 5.000",
        "Até R$ 1.000,00": "Até 1.000",
        "Não estou trabalhando no momento": "Desempregado",
        "Acima de R$ 5.000,00": "Acima de 5.000"
    })
)

# %%
# Aplicar a função
df_leads_l34['estado'] = df_leads_l34['estado'].apply(normalizar_estado)

# Verificar resultado final
print(df_leads_l34['estado'].value_counts(dropna=False))
# Out:
# estado
# SP       10238
# Outro     4744
# MG        1668
# PR         946
# RJ         549
# MA         139
# Name: count, dtype: int64

# %%
df_leads_l34['escolaridade_original'] = df_leads_l34['escolaridade']
df_leads_l34['escolaridade'] = df_leads_l34['escolaridade_original'].apply(normalizar_escolaridade)

df_leads_l34['escolaridade'].value_counts()
# Out:
# escolaridade
# médio completo          12422
# superior completo        2384
# fundamental completo     2004
# Name: count, dtype: int64

# %%
for col in features:
    if col in df_leads_l34.columns:
        df_leads_l34[col] = df_leads_l34[col].astype(str).str.strip().str.lower()

# %%
colunas_excluir = ["data", "email", "whatsapp"]

for coluna in df_leads_l34.columns:
    if coluna not in colunas_excluir:
        print(f"\nColuna: {coluna}")
        print(df_leads_l34[coluna].value_counts(dropna=False))
# Out:
# Coluna: estado
# estado
# SP       10238
# Outro     4744
# MG        1668
# PR         946
# RJ         549
# MA         139
# Name: count, dtype: int64
#
# Coluna: idade
# idade
# 36 - 45 anos        7486
# 26 - 35 anos        5428
# 46 - 55 anos        3584
# até 25 anos         1338
# none                 305
# acima de 56 anos     143
# Name: count, dtype: int64
#
# Coluna: escolaridade
# escolaridade
# médio completo          12422
# superior completo        2384
# fundamental completo     2004
# none                     1474
# Name: count, dtype: int64
#
# Coluna: renda
# renda
# de 1.000 a 3.000    9097
# de 3.000 a 5.000    4638
# até 1.000           1686
# acima de 5.000      1380
# desempregado        1316
# none                 167
# Name: count, dtype: int64
#
# Coluna: estado_civil
# estado_civil
# solteiro(a)                     7264
# casado(a)                       6320
# união estável                   2078
# divorciado(a) ou separado(a)    1987
# outros                           407
# none                             228
# Name: count, dtype: int64
#
# Coluna: filhos
# filhos
# sim     13852
# não      4301
# none      131
# Name: count, dtype: int64
#
# Coluna: escolheu_profissao
# escolheu_profissao
# sonho de criança           6154
# gosta da profissão         5619
# estabilidade de emprego    2811
# prestígio da carreira      1779
# outros                      965
# segurança                   879
# none                         77
# Name: count, dtype: int64
#
# Coluna: dificuldade
# dificuldade
# falta de oportunidades na vida    7140
# financeiro / dinheiro             5713
# falta de tempo                    2935
# idade                             1273
# none                              1223
# Name: count, dtype: int64
#
# Coluna: utm_source
# utm_source
# Facebook-Ads    15873
# google-ads       1939
# INSTAGRAM         205
# TIKTOK            144
# YOUTUBE            57
# None               25
# WHATSAPP           17
# EMAILMKT            9
# fb                  7
# google              6
# search              2
# Name: count, dtype: int64
#
# Coluna: utm_campaign
# utm_campaign
# OPC-L34 | CAPTACAO | CBO | MORNO/QUENTE | BR | 16-05-2025                                3804
# OPC-L34 | CAPTACAO | CBO | QUENTE | BR | 16-05-2025                                      3477
# OPC-L34 | CAPTACAO | ABO | FRIO LAL10% LISTA ALUNO | BR | 16-05-2025 | Teste Criativo    3127
# OPC-L34 | CAPTACAO | CBO | FRIO | BR | 16-05-2025                                        2957
# OPC-L34 | CAPTACAO | ABO | FRIO ABERTO | BR | 16-05-2025                                 1408
# tvfa                                                                                     1176
# OPC-L34 | CAPTACAO | ABO | FRIO LAL10% LISTA ALUNO | BR | 20-05-2025 | Teste Página       669
# L34                                                                                       564
# None                                                                                      430
# pmax                                                                                      405
# search                                                                                    126
# {{campaign.name}}                                                                          98
# OPC-L34 | CAPTACAO | CBO | MORNO\/QUENTE | BR | 16-05-2025                                 30
# opc-l34-teste                                                                               6
# 120224773634130124                                                                          3
# 120224774384420124                                                                          2
# 120224772382650124                                                                          1
# 120224774168030124                                                                          1
# Name: count, dtype: int64
#
# Coluna: utm_medium
# utm_medium
# 00 | LAL 1% LEADS QUALIFICADOS       2245
# 00 | ENVOLVIMENTO 60D                2222
# 00 | PAGINA DE CAPTURA 180D          2120
# 00 | ENVOLVIMENTO E PAGEVIEW 180D    1648
# 00 | SEGUIDORES                      1237
#                                      ...
# 04_mercado_concurso                     1
# COMUNIDADE                              1
# LIVE                                    1
# 01_medio                                1
# 04_keywords_g                           1
# Name: count, Length: 78, dtype: int64
#
# Coluna: utm_content
# utm_content
# ads_001_captacao_video_stories_p1_imagem_sobral_1                                          4064
# ads_005_captacao_video_stories_p1_video_vemai_v1                                           3648
# ads_012_captacao_video_stories_p4_ADS08-CAP-1080x1920-L34-OPC3.0                           3523
# None                                                                                       1210
# ads_008_captacao_video_stories_p2_ADS04-CAP-1080x1920-L34-OPC3.0                           1087
# ads_009_captacao_video_stories_p2_ADS05-CAP-1080x1920-L34-OPC3.0                           1043
# Video_vemai_v1_yt                                                                           723
# ads_004_captacao_video_stories_p1_video_4motivos_v2                                         548
# ads_003_captacao_video_stories_p1_video_mais_um_concurso                                    458
# ads_011_captacao_video_stories_p3_ADS07-CAP-1080x1920-L34-OPC3.0                            312
# Video_5_motivos_yt                                                                          249
# ads_002_captacao_video_stories_p1_imagem_raiz_1                                             235
# ads_010_captacao_video_stories_p2_ADS06-CAP-1080x1920-L34-OPC3                              173
# ads_013_captacao_video_stories_p5_ADS 09 - REQUISITOS POLICIA CIVIL V4 - VERTICAL           158
# Video_mod_tessman_yt                                                                        149
# ad_responsivo                                                                               128
# ads_007_captacao_video_stories_p2_ADS02-CAP-1080x1920-L34-OPC3.0                            118
# {{ad.name}}                                                                                  99
# ads_006_captacao_video_stories_p2_ADS 01 - FASE POLICIA CIVIL V1 [1080x1920] (MODELO 2)      51
# DESCRICAO                                                                                    45
# ads_015_captacao_estatico_stories_p2_L34-ESTÁTICO-02-ST                                      33
# video_ja_se_imaginou                                                                         29
# Video_vendo_esse_distintivo_yt                                                               20
# ADS_01_-_FASE_POLICIA_CIVIL_V1                                                               17
# Video_entrevista_v2_yt                                                                       14
# Video_historia_marcelo_yt                                                                    13
# Video_grandes_mitos_yt                                                                       12
# ADS_09_-_REQUISITOS_POLICIA_CIVIL_V4                                                         10
# Video_lembro_como_se_fosse_ontem                                                              9
# ADS04-CAP-1920x1080-L34-OPC3                                                                  8
# Video_inicial_de_7k                                                                           8
# ads_019_captacao_estatico_stories_p2_L34-CAIXINHA_DE_PERGUNTAS_ST                             7
# video_vou_fazer_um_evento_que_comeca_nessa_terca                                              6
# anuncio1                                                                                      6
# ads_014_captacao_estatico_stories_p2_L34-ESTÁTICO-01-ST                                       6
# Video_vemai_v2_yt                                                                             6
# ads_018_captacao_estatico_stories_p2_L34-NÂO_PERCA_ESSA_CHANCE_ST                             6
# Video_sem_tempo_yt                                                                            4
# ads_020_captacao_estatico_stories_p2_L34-ESTÁTICO-06_ST                                       4
# Video_05_coisas                                                                               4
# Video_vespera_do_concurso_yt                                                                  4
# Video_caminhoneiro_yt                                                                         4
# ads_017_captacao_estatico_stories_p2_L34-ESTÁTICO-04-ST                                       4
# Video_4017_policiais_ganharam_esse_distintivo                                                 4
# Video_posse_camiseta                                                                          3
# ads_016_captacao_estatico_stories_p2_L34-ESTÁTICO-03-ST                                       3
# Video_seguiram_metodologia_yt                                                                 3
# video_marilia_gabriela                                                                        2
# ADS07-CAP-1920x1080-L34-OPC3.0                                                                2
# 120224773634280124                                                                            2
# video_metodologia                                                                             1
# video_5_motivos_l33                                                                           1
# 120224774384440124                                                                            1
# video_metodologia_st                                                                          1
# 120224774384430124                                                                            1
# 120225166666040124                                                                            1
# 120224773634220124                                                                            1
# video_distintivo_e_algema                                                                     1
# QRCODE                                                                                        1
# 120224774168180124                                                                            1
# Name: count, dtype: int64
#
# Coluna: utm_term
# utm_term
# Facebook_Mobile_Reels    3932
# Instagram_Stories        3487
# Instagram_Reels          2969
# Instagram_Feed           2793
# None                     2686
# Facebook_Mobile_Feed     1972
# Facebook_Stories          235
# {{placement}}              99
# Instagram_Explore          55
# Others                     23
# Facebook_Profile_Feed       9
# investigador                6
# an                          4
# Facebook_Desktop_Feed       4
# Facebook_Marketplace        3
# 120224773634150124          2
# 120224774168050124          1
# 120224773634120124          1
# 120225166666050124          1
# 120224774384400124          1
# 120224774384490124          1
# Name: count, dtype: int64
#
# Coluna: escolaridade_original
# escolaridade_original
# Ensino Médio Completo          12422
# Ensino Superior Completo        2384
# Ensino Fundamental Completo     2004
# Outro                           1181
# None                             293
# Name: count, dtype: int64

# %% [markdown]
# # Concat Leads e Resposta Forms

# %%
df_leads_l34 = df_leads_l34.copy()
df_leads_l34_forms = df_leads_l34_forms.copy()

# Junte corretamente
df_leads_l34 = pd.concat([df_leads_l34, df_leads_l34_forms], ignore_index=True)
df_leads_l34.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20757 entries, 0 to 20756
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   data                   20757 non-null  object
#  1   estado                 20757 non-null  object
#  2   idade                  20757 non-null  object
#  3   escolaridade           20757 non-null  object
#  4   renda                  20757 non-null  object
#  5   estado_civil           20757 non-null  object
#  6   filhos                 20757 non-null  object
#  7   escolheu_profissao     20757 non-null  object
#  8   dificuldade            20757 non-null  object
#  9   email                  20757 non-null  object
#  10  whatsapp               20755 non-null  object
#  11  utm_source             18259 non-null  object
#  12  utm_campaign           17854 non-null  object
#  13  utm_medium             17454 non-null  object
#  14  utm_content            17074 non-null  object
#  15  utm_term               15598 non-null  object
#  16  escolaridade_original  17991 non-null  object
# dtypes: object(17)
# memory usage: 2.7+ MB

# %%
# Conta quantos e-mails aparecem mais de uma vez
duplicados = df_leads_l34['email'].duplicated(keep=False)

# Exibe o total de duplicados (incluindo todas as ocorrências)
total_duplicados = duplicados.sum()
print(f"Total de e-mails duplicados (todas ocorrências): {total_duplicados}")
# Out:
# Total de e-mails duplicados (todas ocorrências): 3948

# %%
emails_duplicados_unicos = df_leads_l34['email'][duplicados].nunique()
print(f"Total de e-mails diferentes que estão duplicados: {emails_duplicados_unicos}")
# Out:
# Total de e-mails diferentes que estão duplicados: 1945

# %%
# Normalizar e deduplicar e-mails
if 'email' in df_leads_l34.columns:
    df_leads_l34['email'] = df_leads_l34['email'].astype(str).str.lower().str.strip()

df_leads_l34 = df_leads_l34.drop_duplicates(subset='email', keep='first')

df_leads_l34["lancamentos"] = "L34"

df_leads_l34['data'] = pd.to_datetime(df_leads_l34['data'], errors='coerce')

df_leads_l34["comprou"] = df_leads_l34["email"].isin(df_alunos["email"]).astype(int)

df_leads_l34.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18714 entries, 0 to 20751
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   data                   18714 non-null  datetime64[ns]
#  1   estado                 18714 non-null  object
#  2   idade                  18714 non-null  object
#  3   escolaridade           18714 non-null  object
#  4   renda                  18714 non-null  object
#  5   estado_civil           18714 non-null  object
#  6   filhos                 18714 non-null  object
#  7   escolheu_profissao     18714 non-null  object
#  8   dificuldade            18714 non-null  object
#  9   email                  18714 non-null  object
#  10  whatsapp               18712 non-null  object
#  11  utm_source             18259 non-null  object
#  12  utm_campaign           17854 non-null  object
#  13  utm_medium             17454 non-null  object
#  14  utm_content            17074 non-null  object
#  15  utm_term               15598 non-null  object
#  16  escolaridade_original  17991 non-null  object
#  17  lancamentos            18714 non-null  object
#  18  comprou                18714 non-null  int32
# dtypes: datetime64[ns](1), int32(1), object(17)
# memory usage: 2.8+ MB

# %%
colunas_excluir = ["data", "email", "whatsapp"]

for coluna in df_leads_l34.columns:
    if coluna not in colunas_excluir:
        print(f"\nColuna: {coluna}")
        print(df_leads_l34[coluna].value_counts(dropna=False))
# Out:
# Coluna: estado
# estado
# SP       10504
# Outro     4744
# MG        1701
# PR         967
# RJ         561
# MA         145
# RS          18
# BA          14
# SC          14
# PE          12
# CE          12
# GO           9
# AL           6
# PB           1
# RN           1
# DF           1
# PA           1
# CE           1
# AM           1
# Conde        1
# Name: count, dtype: int64
#
# Coluna: idade
# idade
# 36 - 45 anos        7661
# 26 - 35 anos        5528
# 46 - 55 anos        3708
# até 25 anos         1362
# none                 305
# acima de 56 anos     150
# Name: count, dtype: int64
#
# Coluna: escolaridade
# escolaridade
# médio completo            12704
# superior completo          2438
# fundamental completo       2061
# none                       1481
# superior incompleto          17
# técnico                       6
# fundamental incompleto        4
# médio incompleto              3
# Name: count, dtype: int64
#
# Coluna: renda
# renda
# de 1.000 a 3.000    9314
# de 3.000 a 5.000    4721
# até 1.000           1750
# acima de 5.000      1398
# desempregado        1364
# none                 167
# Name: count, dtype: int64
#
# Coluna: estado_civil
# estado_civil
# solteiro(a)                        7423
# casado(a)                          6486
# união estável                      2131
# divorciado(a) ou separado(a)       2038
# outros                              407
# none                                228
# morando junto mais nao no papel       1
# Name: count, dtype: int64
#
# Coluna: filhos
# filhos
# sim     14191
# não      4392
# none      131
# Name: count, dtype: int64
#
# Coluna: escolheu_profissao
# escolheu_profissao
# sonho de criança                                                                                                                                                                                                 6297
# gosta da profissão                                                                                                                                                                                               5765
# estabilidade de emprego                                                                                                                                                                                          2890
# prestígio da carreira                                                                                                                                                                                            1809
# outros                                                                                                                                                                                                            965
# segurança                                                                                                                                                                                                         896
# none                                                                                                                                                                                                               77
# reformado na pmmg                                                                                                                                                                                                   1
# inspiração meu pai                                                                                                                                                                                                  1
# todos os ponto acima.                                                                                                                                                                                               1
# todas as opções anteriores                                                                                                                                                                                          1
# estabilidade e amor a profissão                                                                                                                                                                                     1
# trocar de instituição                                                                                                                                                                                               1
# sempre gostei da profissão,e pela também pela estabilidade de emprego                                                                                                                                               1
# todo mundo que me conhece fala que eu tenho cara de polícia, e como eu já gosto da profissão resolvi arriscar.                                                                                                      1
# quando novo perdi a minha única oportunidade de servir o batalhão caveira no exército brasileiro de itu,por conta de uma paixão de adolescente, me arrependo até os dias de hj minha farda jogada aos porcos.       1
# detetive                                                                                                                                                                                                            1
# pra mim é uma honra ter esse mérito! e amo fazer o trabalho do bem!                                                                                                                                                 1
# quero novo conhecimento                                                                                                                                                                                             1
# a lei foi instruída pelo profeta moisés pelo criador jeová                                                                                                                                                          1
# ganhar um bom dinheiro                                                                                                                                                                                              1
# já trabalhei como escrivão ad hoc                                                                                                                                                                                   1
# Name: count, dtype: int64
#
# Coluna: dificuldade
# dificuldade
# falta de oportunidades na vida    7140
# financeiro / dinheiro             5914
# falta de tempo                    3020
# idade                             1321
# none                              1251
# falta de base escolar               65
# falta de oportunidade                3
# Name: count, dtype: int64
#
# Coluna: utm_source
# utm_source
# Facebook-Ads    15873
# google-ads       1939
# NaN               430
# INSTAGRAM         205
# TIKTOK            144
# YOUTUBE            57
# None               25
# WHATSAPP           17
# EMAILMKT            9
# fb                  7
# google              6
# search              2
# Name: count, dtype: int64
#
# Coluna: utm_campaign
# utm_campaign
# OPC-L34 | CAPTACAO | CBO | MORNO/QUENTE | BR | 16-05-2025                                3804
# OPC-L34 | CAPTACAO | CBO | QUENTE | BR | 16-05-2025                                      3477
# OPC-L34 | CAPTACAO | ABO | FRIO LAL10% LISTA ALUNO | BR | 16-05-2025 | Teste Criativo    3127
# OPC-L34 | CAPTACAO | CBO | FRIO | BR | 16-05-2025                                        2957
# OPC-L34 | CAPTACAO | ABO | FRIO ABERTO | BR | 16-05-2025                                 1408
# tvfa                                                                                     1176
# OPC-L34 | CAPTACAO | ABO | FRIO LAL10% LISTA ALUNO | BR | 20-05-2025 | Teste Página       669
# L34                                                                                       564
# NaN                                                                                       430
# None                                                                                      430
# pmax                                                                                      405
# search                                                                                    126
# {{campaign.name}}                                                                          98
# OPC-L34 | CAPTACAO | CBO | MORNO\/QUENTE | BR | 16-05-2025                                 30
# opc-l34-teste                                                                               6
# 120224773634130124                                                                          3
# 120224774384420124                                                                          2
# 120224772382650124                                                                          1
# 120224774168030124                                                                          1
# Name: count, dtype: int64
#
# Coluna: utm_medium
# utm_medium
# 00 | LAL 1% LEADS QUALIFICADOS       2245
# 00 | ENVOLVIMENTO 60D                2222
# 00 | PAGINA DE CAPTURA 180D          2120
# 00 | ENVOLVIMENTO E PAGEVIEW 180D    1648
# 00 | SEGUIDORES                      1237
#                                      ...
# 01_medio                                1
# COMUNIDADE                              1
# 04_mercado_concurso                     1
# 04_keywords_g                           1
# LIVE                                    1
# Name: count, Length: 79, dtype: int64
#
# Coluna: utm_content
# utm_content
# ads_001_captacao_video_stories_p1_imagem_sobral_1                   4064
# ads_005_captacao_video_stories_p1_video_vemai_v1                    3648
# ads_012_captacao_video_stories_p4_ADS08-CAP-1080x1920-L34-OPC3.0    3523
# None                                                                1210
# ads_008_captacao_video_stories_p2_ADS04-CAP-1080x1920-L34-OPC3.0    1087
#                                                                     ...
# 120225166666040124                                                     1
# 120224773634220124                                                     1
# QRCODE                                                                 1
# video_distintivo_e_algema                                              1
# 120224774168180124                                                     1
# Name: count, Length: 61, dtype: int64
#
# Coluna: utm_term
# utm_term
# Facebook_Mobile_Reels    3932
# Instagram_Stories        3487
# Instagram_Reels          2969
# Instagram_Feed           2793
# None                     2686
# Facebook_Mobile_Feed     1972
# NaN                       430
# Facebook_Stories          235
# {{placement}}              99
# Instagram_Explore          55
# Others                     23
# Facebook_Profile_Feed       9
# investigador                6
# an                          4
# Facebook_Desktop_Feed       4
# Facebook_Marketplace        3
# 120224773634150124          2
# 120224774168050124          1
# 120224773634120124          1
# 120225166666050124          1
# 120224774384400124          1
# 120224774384490124          1
# Name: count, dtype: int64
#
# Coluna: escolaridade_original
# escolaridade_original
# Ensino Médio Completo          12422
# Ensino Superior Completo        2384
# Ensino Fundamental Completo     2004
# Outro                           1181
# NaN                              430
# None                             293
# Name: count, dtype: int64
#
# Coluna: lancamentos
# lancamentos
# L34    18714
# Name: count, dtype: int64
#
# Coluna: comprou
# comprou
# 0    18709
# 1        5
# Name: count, dtype: int64

# %% [markdown]
# # Adicionar Valores de Investimento de Trafégo

# %%
df_dados_invest_face.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1012 entries, 0 to 1011
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   date                       1012 non-null   object
#  1   campaign                   1012 non-null   object
#  2   adset_name                 1012 non-null   object
#  3   ad_name                    1012 non-null   object
#  4   spend                      1012 non-null   float64
#  5   impressions                1012 non-null   int64
#  6   actions_link_click         1012 non-null   int64
#  7   actions_landing_page_view  1012 non-null   int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 63.4+ KB

# %%
df_dados_invest_face["spend"].sum()
# Out:
# 33474.63

# %%
df_dados_invest_google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         60 non-null     object
#  1   campaign     60 non-null     object
#  2   clicks       60 non-null     int64
#  3   spend        60 non-null     float64
#  4   impressions  60 non-null     int64
#  5   conversions  60 non-null     int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 2.9+ KB

# %%
df_dados_invest_google["spend"].sum()
# Out:
# 10931.355000000003

# %%
# Normalizar colunas
df_dados_invest_face['ad_name'] = df_dados_invest_face['ad_name'].str.strip().str.lower()
df_leads_l34['utm_content'] = df_leads_l34['utm_content'].str.strip().str.lower()

# Agrupar leads por utm_content e puxar o valor mais comum de lancamentos
leads_por_anuncio = (
    df_leads_l34.groupby('utm_content')
    .agg(num_leads=('utm_content', 'count'),
         lancamentos=('lancamentos', lambda x: x.mode().iloc[0] if not x.mode().empty else None))
    .reset_index()
)
leads_por_anuncio.rename(columns={'utm_content': 'ad_name'}, inplace=True)

# Agrupar investimento
investimento_por_anuncio = df_dados_invest_face.groupby('ad_name')['spend'].sum().reset_index()

# Merge leads + investimento
df_cpl_face = pd.merge(investimento_por_anuncio, leads_por_anuncio, on='ad_name', how='left')

# Pegar utm_source dominante por anúncio
utm_por_anuncio = (
    df_leads_l34
    .groupby('utm_content')['utm_source']
    .agg(lambda x: x.mode().iloc[0] if not x.mode().empty else None)
    .reset_index()
    .rename(columns={'utm_content': 'ad_name'})
)

# Merge com df_cpl_face
df_cpl_face = pd.merge(df_cpl_face, utm_por_anuncio, on='ad_name', how='left')

# Agora sim!
df_cpl_face['spend'] = (df_cpl_face['spend']) * df_cpl_face['utm_source'].map(taxa_resposta_por_canal)

# Preencher NaNs
df_cpl_face['num_leads'] = df_cpl_face['num_leads'].fillna(0)

# Calcular CPL
df_cpl_face['cpl'] = df_cpl_face.apply(
    lambda row: row['spend'] / row['num_leads'] if row['num_leads'] > 0 else None,
    axis=1
)

# Total row
total_row = pd.DataFrame([{
    'ad_name': 'TOTAL',
    'spend': float(df_cpl_face['spend'].sum()),
    'num_leads': float(df_cpl_face['num_leads'].sum()),
    'cpl': float(df_cpl_face['spend'].sum()) / float(df_cpl_face['num_leads'].sum())
        if df_cpl_face['num_leads'].sum() > 0 else None,
    'lancamentos': None
}])

# Concatenar
df_cpl_face = pd.concat([df_cpl_face, total_row], ignore_index=True)

# %%
# Reordenar colunas colocando 'lancamentos' primeiro
cols = ['lancamentos'] + [col for col in df_cpl_face.columns if col != 'lancamentos']
df_cpl_face = df_cpl_face[cols]

# Renomear colunas
df_cpl_face.rename(columns={
    'ad_name': 'criativo',
    'spend': 'investimento',
    'num_leads': 'leads'
}, inplace=True)

# Ajustar formatos
df_cpl_face['leads'] = df_cpl_face['leads'].astype(int)
df_cpl_face['cpl'] = df_cpl_face['cpl'].round(2)
df_cpl_face['investimento'] = df_cpl_face['investimento'].round(2)  # opcional

pd.set_option('display.max_rows', 100)  # ou mais, se quiser
display(df_cpl_face)
# Out:
#    lancamentos                                           criativo  \
# 0          NaN                  ads 14 - calendário v2 - vertical
# 1          NaN                    ads 16 - carteira v2 - vertical
# 2          NaN   ads 18 - quanto pesa um distintivo v2 - vertical
# 3          NaN                     ads13-cap-1080x1920-l34-opc3.0
# 4          NaN                     ads15-cap-1080x1920-l34-opc3.0
# 5          L34  ads_001_captacao_video_stories_p1_imagem_sobral_1
# 6          L34    ads_002_captacao_video_stories_p1_imagem_raiz_1
# 7          L34  ads_003_captacao_video_stories_p1_video_mais_u...
# 8          L34  ads_004_captacao_video_stories_p1_video_4motiv...
# 9          L34   ads_005_captacao_video_stories_p1_video_vemai_v1
# 10         L34  ads_006_captacao_video_stories_p2_ads 01 - fas...
# 11         L34  ads_007_captacao_video_stories_p2_ads02-cap-10...
# 12         L34  ads_008_captacao_video_stories_p2_ads04-cap-10...
# 13         L34  ads_009_captacao_video_stories_p2_ads05-cap-10...
# 14         L34  ads_010_captacao_video_stories_p2_ads06-cap-10...
# 15         L34  ads_011_captacao_video_stories_p3_ads07-cap-10...
# 16         L34  ads_012_captacao_video_stories_p4_ads08-cap-10...
# 17         L34  ads_013_captacao_video_stories_p5_ads 09 - req...
# 18         L34  ads_014_captacao_estatico_stories_p2_l34-estát...
# 19         L34  ads_015_captacao_estatico_stories_p2_l34-estát...
# 20         L34  ads_016_captacao_estatico_stories_p2_l34-estát...
# 21         L34  ads_017_captacao_estatico_stories_p2_l34-estát...
# 22         L34  ads_018_captacao_estatico_stories_p2_l34-nâo_p...
# 23         L34  ads_019_captacao_estatico_stories_p2_l34-caixi...
# 24         L34  ads_020_captacao_estatico_stories_p2_l34-estát...
# 25        None                                              TOTAL
#
#     investimento  leads    utm_source    cpl
# 0            NaN      0           NaN    NaN
# 1            NaN      0           NaN    NaN
# 2            NaN      0           NaN    NaN
# 3            NaN      0           NaN    NaN
# 4            NaN      0           NaN    NaN
# 5        7817.70   4064  Facebook-Ads   1.92
# 6         660.19    235  Facebook-Ads   2.81
# 7        1360.31    458  Facebook-Ads   2.97
# 8        1163.66    548  Facebook-Ads   2.12
# 9        6690.27   3648  Facebook-Ads   1.83
# 10        113.34     51  Facebook-Ads   2.22
# 11        228.41    118  Facebook-Ads   1.94
# 12       1517.85   1087  Facebook-Ads   1.40
# 13       1232.71   1043  Facebook-Ads   1.18
# 14        288.40    173  Facebook-Ads   1.67
# 15        450.86    312  Facebook-Ads   1.45
# 16       4947.16   3523  Facebook-Ads   1.40
# 17        264.84    158  Facebook-Ads   1.68
# 18         40.84      6  Facebook-Ads   6.81
# 19         97.02     33  Facebook-Ads   2.94
# 20         38.29      3  Facebook-Ads  12.76
# 21         31.25      4  Facebook-Ads   7.81
# 22         21.31      6  Facebook-Ads   3.55
# 23         38.83      7  Facebook-Ads   5.55
# 24         38.57      4  Facebook-Ads   9.64
# 25      27041.81  15481           NaN   1.75

# %%
df_cpl_face.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   lancamentos   20 non-null     object
#  1   criativo      26 non-null     object
#  2   investimento  21 non-null     float64
#  3   leads         26 non-null     int32
#  4   utm_source    20 non-null     object
#  5   cpl           21 non-null     float64
# dtypes: float64(2), int32(1), object(3)
# memory usage: 1.2+ KB

# %%
# Limpar e normalizar campanhas do Google Ads
df_dados_invest_google['campaign'] = df_dados_invest_google['campaign'].str.strip().str.lower()

# ➕ Normalizar categorias específicas para facilitar o merge
df_dados_invest_google['campaign'] = (
    df_dados_invest_google['campaign']
    .replace({
        r'.*search.*': 'search',
        r'.*pmax.*': 'pmax',
        r'.*tva.*': 'tvfa'
    }, regex=True)
)

# Leads: apenas limpar, sem normalizar nomes
df_leads_l34['utm_campaign'] = df_leads_l34['utm_campaign'].str.strip().str.lower()

# %%
# Agrupar leads por utm_content e puxar o valor mais comum de lancamentos
leads_por_anuncio = (
    df_leads_l34.groupby('utm_campaign')
    .agg(num_leads=('utm_campaign', 'count'),
         lancamentos=('lancamentos', lambda x: x.mode().iloc[0] if not x.mode().empty else None))
    .reset_index()
)
leads_por_anuncio.rename(columns={'utm_campaign': 'campaign'}, inplace=True)

df_dados_invest_google['spend'] = df_dados_invest_google['spend'].astype(str)

# Corrigir valores numéricos de spend com vírgula como decimal e ponto como milhar
df_dados_invest_google['spend'] = (
    df_dados_invest_google['spend']
    .str.replace('.', '', regex=False)   # remove milhar
    .str.replace(',', '.', regex=False)  # troca decimal
    .astype(float)
)

# Agrupar investimento
investimento_por_anuncio = df_dados_invest_google.groupby('campaign')['spend'].sum().reset_index()

# Merge leads + investimento
df_cpl_google = pd.merge(investimento_por_anuncio, leads_por_anuncio, on='campaign', how='left')

# Pegar utm_source dominante por anúncio
utm_por_anuncio = (
    df_leads_l34
    .groupby('utm_campaign')['utm_source']
    .agg(lambda x: x.mode().iloc[0] if not x.mode().empty else None)
    .reset_index()
    .rename(columns={'utm_campaign': 'campaign'})
)

# Merge com df_cpl_face
df_cpl_google = pd.merge(df_cpl_google, utm_por_anuncio, on='campaign', how='left')

# Agora sim!
df_cpl_google['spend'] = (df_cpl_google['spend'] / 1000) * df_cpl_google['utm_source'].map(taxa_resposta_por_canal)

# Preencher NaNs
df_cpl_google['num_leads'] = df_cpl_google['num_leads'].fillna(0)

# Calcular CPL
df_cpl_google['cpl'] = df_cpl_google.apply(
    lambda row: row['spend'] / row['num_leads'] if row['num_leads'] > 0 else None,
    axis=1
)

# Total row
total_row = pd.DataFrame([{
    'campaign': 'TOTAL',
    'spend': float(df_cpl_google['spend'].sum()),
    'num_leads': float(df_cpl_google['num_leads'].sum()),
    'cpl': float(df_cpl_google['spend'].sum()) / float(df_cpl_google['num_leads'].sum())
        if df_cpl_google['num_leads'].sum() > 0 else None,
    'lancamentos': None
}])

# Concatenar
df_cpl_google = pd.concat([df_cpl_google, total_row], ignore_index=True)

# %%
# Reordenar colunas colocando 'lancamentos' primeiro
cols = ['lancamentos'] + [col for col in df_cpl_google.columns if col != 'lancamentos']
df_cpl_google = df_cpl_google[cols]

# Renomear colunas
df_cpl_google.rename(columns={
    'campaign': 'campanha',
    'spend': 'investimento',
    'num_leads': 'leads'
}, inplace=True)

# Ajustar formatos
df_cpl_google['leads'] = df_cpl_google['leads'].astype(int)
df_cpl_google['cpl'] = df_cpl_google['cpl'].round(2)
df_cpl_google['investimento'] = df_cpl_google['investimento'].round(2) 

pd.set_option('display.max_rows', 100)  # ou mais, se quiser
display(df_cpl_google)
# Out:
#   lancamentos campanha  investimento  leads  utm_source   cpl
# 0         L34     pmax       1715.45    405  google-ads  4.24
# 1         L34   search       1080.57    126  google-ads  8.58
# 2         L34     tvfa       6189.10   1176  google-ads  5.26
# 3        None    TOTAL       8985.12   1707         NaN  5.26

# %% [markdown]
# # Concat `df_leads` com `df_lead_novo`

# %%
# Recarregue os dois DataFrames originais se possível (ou copie)
df_leads = df_leads.copy()
df_leads_l34 = df_leads_l34.copy()

# Junte corretamente
df_leads = pd.concat([df_leads, df_leads_l34], ignore_index=True)
print("Total:", len(df_leads))
# Out:
# Total: 29577

# %%
df_leads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29577 entries, 0 to 29576
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   data                   29577 non-null  datetime64[ns]
#  1   lancamentos            29577 non-null  object
#  2   email                  29577 non-null  object
#  3   whatsapp               29575 non-null  object
#  4   estado                 29577 non-null  object
#  5   idade                  29577 non-null  object
#  6   escolaridade           29577 non-null  object
#  7   renda                  29577 non-null  object
#  8   estado_civil           29577 non-null  object
#  9   filhos                 29577 non-null  object
#  10  escolheu_profissao     29577 non-null  object
#  11  dificuldade            29577 non-null  object
#  12  comprou                29577 non-null  int32
#  13  utm_source             29076 non-null  object
#  14  utm_medium             28144 non-null  object
#  15  utm_campaign           28694 non-null  object
#  16  utm_content            27166 non-null  object
#  17  utm_term               22127 non-null  object
#  18  escolaridade_original  17991 non-null  object
# dtypes: datetime64[ns](1), int32(1), object(17)
# memory usage: 4.2+ MB

# %%
colunas_excluir = ["data", "email", "whatsapp"]

for coluna in df_leads.columns:
    if coluna not in colunas_excluir:
        print(f"\nColuna: {coluna}")
        print(df_leads[coluna].value_counts(dropna=False))
# Out:
# Coluna: lancamentos
# lancamentos
# L34    18714
# L32     4875
# L31     2657
# L33     2461
# L30      352
# L28      275
# L29      243
# Name: count, dtype: int64
#
# Coluna: estado
# estado
# SP       18510
# Outro     4960
# MG        2736
# RJ        2054
# PR        1008
# MA         180
# BA          27
# RS          22
# SC          17
# GO          17
# CE          14
# PE          13
# AL           8
# DF           2
# RN           2
# AM           2
# RR           1
# PB           1
# PA           1
# CE           1
# Conde        1
# Name: count, dtype: int64
#
# Coluna: idade
# idade
# 36 - 45 anos        11845
# 26 - 35 anos         8898
# 46 - 55 anos         6056
# até 25 anos          2140
# acima de 56 anos      333
# none                  305
# Name: count, dtype: int64
#
# Coluna: escolaridade
# escolaridade
# médio completo            20667
# superior completo          4288
# fundamental completo       2982
# none                       1481
# superior incompleto          97
# técnico                      31
# médio incompleto             16
# fundamental incompleto       15
# Name: count, dtype: int64
#
# Coluna: renda
# renda
# de 1.000 a 3.000    15016
# de 3.000 a 5.000     7237
# até 1.000            2777
# desempregado         2229
# acima de 5.000       2151
# none                  167
# Name: count, dtype: int64
#
# Coluna: estado_civil
# estado_civil
# solteiro(a)                        11843
# casado(a)                          10621
# união estável                       3251
# divorciado(a) ou separado(a)        3213
# outros                               407
# none                                 228
# viúvo(a)                              12
# divorciado(a)                          1
# morando junto mais nao no papel        1
# Name: count, dtype: int64
#
# Coluna: filhos
# filhos
# sim     22000
# não      7446
# none      131
# Name: count, dtype: int64
#
# Coluna: escolheu_profissao
# escolheu_profissao
# sonho de criança                                                                                                                                                                                                 10153
# gosta da profissão                                                                                                                                                                                                9561
# estabilidade de emprego                                                                                                                                                                                           4977
# prestígio da carreira                                                                                                                                                                                             2838
# segurança                                                                                                                                                                                                          991
# outros                                                                                                                                                                                                             965
# none                                                                                                                                                                                                                77
# reformado na pmmg                                                                                                                                                                                                    1
# inspiração meu pai                                                                                                                                                                                                   1
# todos os ponto acima.                                                                                                                                                                                                1
# todas as opções anteriores                                                                                                                                                                                           1
# estabilidade e amor a profissão                                                                                                                                                                                      1
# trocar de instituição                                                                                                                                                                                                1
# sempre gostei da profissão,e pela também pela estabilidade de emprego                                                                                                                                                1
# todo mundo que me conhece fala que eu tenho cara de polícia, e como eu já gosto da profissão resolvi arriscar.                                                                                                       1
# quando novo perdi a minha única oportunidade de servir o batalhão caveira no exército brasileiro de itu,por conta de uma paixão de adolescente, me arrependo até os dias de hj minha farda jogada aos porcos.        1
# detetive                                                                                                                                                                                                             1
# pra mim é uma honra ter esse mérito! e amo fazer o trabalho do bem!                                                                                                                                                  1
# quero novo conhecimento                                                                                                                                                                                              1
# a lei foi instruída pelo profeta moisés pelo criador jeová                                                                                                                                                           1
# ganhar um bom dinheiro                                                                                                                                                                                               1
# já trabalhei como escrivão ad hoc                                                                                                                                                                                    1
# Name: count, dtype: int64
#
# Coluna: dificuldade
# dificuldade
# financeiro / dinheiro             10311
# falta de oportunidades na vida     7140
# falta de tempo                     5613
# idade                              2365
# falta de base escolar              1596
# falta de oportunidade              1301
# none                               1251
# Name: count, dtype: int64
#
# Coluna: comprou
# comprou
# 0    29312
# 1      265
# Name: count, dtype: int64
#
# Coluna: utm_source
# utm_source
# Facebook-Ads              15873
# tva                        3096
# instagram_feed             2261
# google-ads                 1939
# instagram_reels            1762
# instagram_stories          1480
# NaN                         430
# facebook_mobile_reels       385
# search                      374
# facebook_mobile_feed        372
# instagram                   228
# INSTAGRAM                   205
# TIKTOK                      144
# whatsapp                    134
# facebook_right_column       132
# youtube                     121
# email                       114
# None                         71
# YOUTUBE                      57
# facebook_stories             56
# bio                          35
# instagram_explore            28
# vadeos                       25
# grupos antigos               23
# others                       21
# wpp                          21
# stories                      19
# canal                        17
# WHATSAPP                     17
# qrcode                       16
# manychat                     15
# ytb                          12
# live                         12
# email mkt                    11
# ig                           10
# EMAILMKT                      9
# fb                            7
# ref_instagram                 6
# google                        6
# lista evento                  5
# comunidade                    4
# tiktok                        4
# yt_org                        3
# telegram                      3
# newsletter                    3
# vadeo                         2
# geral                         2
# facebook                      2
# yt-org                        1
# ref_google                    1
# instagram_profile_feed        1
# facebook_desktop_feed         1
# grupos                        1
# Name: count, dtype: int64
#
# Coluna: utm_medium
# utm_medium
# 00 | LAL 1% LEADS QUALIFICADOS       2245
# 00 | ENVOLVIMENTO 60D                2222
# 00 | PAGINA DE CAPTURA 180D          2120
# 04_ll_10_lista_de_alunos             2113
# 00 | ENVOLVIMENTO E PAGEVIEW 180D    1648
#                                      ...
# 04_ll_10_lista_de_alunos_g1wp           1
# 04_ll_10_lista_de_alunos_d2wp           1
# COMUNIDADE                              1
# 04_keywords_g                           1
# live                                    1
# Name: count, Length: 135, dtype: int64
#
# Coluna: utm_campaign
# utm_campaign
# l32                                                                                      4853
# opc-l34 | captacao | cbo | morno/quente | br | 16-05-2025                                3804
# opc-l34 | captacao | cbo | quente | br | 16-05-2025                                      3477
# opc-l34 | captacao | abo | frio lal10% lista aluno | br | 16-05-2025 | teste criativo    3127
# opc-l34 | captacao | cbo | frio | br | 16-05-2025                                        2957
# l31                                                                                      2464
# l33                                                                                      2421
# opc-l34 | captacao | abo | frio aberto | br | 16-05-2025                                 1408
# tvfa                                                                                     1176
# opc-l34 | captacao | abo | frio lal10% lista aluno | br | 20-05-2025 | teste página       669
# l34                                                                                       564
# None                                                                                      453
# NaN                                                                                       430
# pmax                                                                                      405
# l30                                                                                       376
# l28                                                                                       293
# l29                                                                                       254
# search                                                                                    126
# {{campaign.name}}                                                                          98
# youtube                                                                                    76
# instagram                                                                                  69
# opc-l34 | captacao | cbo | morno\/quente | br | 16-05-2025                                 30
# whatsapp                                                                                   23
# opc-l34-teste                                                                               6
# e-mail                                                                                      5
# lista de email                                                                              3
# 120224773634130124                                                                          3
# 120224774384420124                                                                          2
# facebook                                                                                    2
# telegram                                                                                    1
# 120224772382650124                                                                          1
# 120224774168030124                                                                          1
# Name: count, dtype: int64
#
# Coluna: utm_content
# utm_content
# ads_001_captacao_video_stories_p1_imagem_sobral_1                   4064
# ads_005_captacao_video_stories_p1_video_vemai_v1                    3648
# ads_012_captacao_video_stories_p4_ads08-cap-1080x1920-l34-opc3.0    3523
# video_vemai_v1                                                      3283
# None                                                                1981
#                                                                     ...
# video_posse_camiseta_yt                                                1
# video                                                                  1
# video_exige_apenas_nivel_medio                                         1
# imagem_sobral_2                                                        1
# video_como_se_fosse_ontem_yt                                           1
# Name: count, Length: 220, dtype: int64
#
# Coluna: utm_term
# utm_term
# None                     7020
# Facebook_Mobile_Reels    3932
# frio                     3869
# Instagram_Stories        3487
# Instagram_Reels          2969
# Instagram_Feed           2793
# quente                   2615
# Facebook_Mobile_Feed     1972
# NaN                       430
# Facebook_Stories          235
# {{placement}}              99
# Instagram_Explore          55
# morno                      45
# Others                     23
# Facebook_Profile_Feed       9
# investigador                6
# an                          4
# Facebook_Desktop_Feed       4
# Facebook_Marketplace        3
# 120224773634150124          2
# 120224774168050124          1
# 120224773634120124          1
# 120225166666050124          1
# 120224774384400124          1
# 120224774384490124          1
# Name: count, dtype: int64
#
# Coluna: escolaridade_original
# escolaridade_original
# Ensino Médio Completo          12422
# NaN                            11293
# Ensino Superior Completo        2384
# Ensino Fundamental Completo     2004
# Outro                           1181
# None                             293
# Name: count, dtype: int64

# %%
df_leads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29577 entries, 0 to 29576
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   data                   29577 non-null  datetime64[ns]
#  1   lancamentos            29577 non-null  object
#  2   email                  29577 non-null  object
#  3   whatsapp               29575 non-null  object
#  4   estado                 29577 non-null  object
#  5   idade                  29577 non-null  object
#  6   escolaridade           29577 non-null  object
#  7   renda                  29577 non-null  object
#  8   estado_civil           29577 non-null  object
#  9   filhos                 29577 non-null  object
#  10  escolheu_profissao     29577 non-null  object
#  11  dificuldade            29577 non-null  object
#  12  comprou                29577 non-null  int32
#  13  utm_source             29076 non-null  object
#  14  utm_medium             28144 non-null  object
#  15  utm_campaign           28694 non-null  object
#  16  utm_content            27166 non-null  object
#  17  utm_term               22127 non-null  object
#  18  escolaridade_original  17991 non-null  object
# dtypes: datetime64[ns](1), int32(1), object(17)
# memory usage: 4.2+ MB

# %%
df_leads['whatsapp'] = df_leads['whatsapp'].astype(str)
df_alunos['whatsapp'] = df_alunos['whatsapp'].astype(str)

# %%
output_dir = Path.cwd().parent / "dados"

df_leads.to_parquet(output_dir / "leads.parquet", index=False)
df_alunos.to_parquet(output_dir / "alunos.parquet", index=False)
df_dados_invest_face.to_parquet(output_dir / "invest_face.parquet", index=False)
df_dados_invest_google.to_parquet(output_dir / "invest_google.parquet", index=False)

# %%
output_path = Path.cwd().parent / "dados"
df_cpl_face.to_parquet(output_path / "invest_trafego_face.parquet", index=False)
df_cpl_google.to_parquet(output_path / "invest_trafego_google.parquet", index=False)

# %%
# Gerar timestamp com fuso horário de SP
fuso_brasil = pytz.timezone("America/Sao_Paulo")
agora_brasil = datetime.now(fuso_brasil)

# Caminho seguro para salvar
config_path = Path.cwd().parent / "config" / "ultima_atualizacao.txt"
with open(config_path, "w") as f:
    f.write(agora_brasil.strftime("%Y-%m-%d %H:%M:%S"))

# %%
try:
    caminho_data = Path.cwd().parent / "config" / "ultima_atualizacao.txt"
    with open(caminho_data, "r") as f:
        texto = f.read()
        data_atualizacao = datetime.strptime(texto, "%Y-%m-%d %H:%M:%S")
        data_atualizacao_formatada = data_atualizacao.strftime("%d/%m/%Y %H:%M")
except Exception:
    data_atualizacao_formatada = "Desconhecida"

# %%
f"**Última atualização:** {data_atualizacao_formatada}"
# Out:
# '**Última atualização:** 28/05/2025 08:11'
